# %% [markdown]
# # <h1> Task : Calculator                 (Version 1) </h1>

# %%
import math

space = "\n\t\t\t\t\t"
separate = "\n--------------------------------------------------------------------------------------------------------"
options = ('0','1', '2', '3', '4', '5', '6' ,'exit') 


Menu = """Select an operation.\n
        0.All Operations 
        1.Add
        2.Subtract
        3.Multiply
        4.Divide
        5.Power
        6.Square root
        exit"""

def Display (calcul,count):
    
    while True:
            
            Result = calcul.Result(count)
            
            width = len(Result)

            print(space,'+-' + '-' * width + '-+')

            for line in calcul.Border(Result, width):
                print(space,'| {0:^{1}} |'.format(line, width))

            print(space,'+-' + '-'*(width) + '-+')

            if choice == '0' and int(count) < 6 :
                count = str(int(count)+1)
            else:
                break;
                
                                              
        
class Calculator:
    
    def __init__(self,Number1,Number2):
        self.Number1 = Number1
        self.Number2 = Number2
    
    
    def add(self,x,y):
        
        return x + y 
    
    def subtract(self,x,y):
        
        return x - y
    
    def multiply(self,x,y):
        
        return x * y
    
    def power (self,x,y):
        
        return x ** y
    
    def square_root (self,x,y):
        
        if x < 0:
            x = x * (-1)
            
        return math.sqrt(x)
    
    def divide(self,x,y): 
        if y == 0: 
            return "You can't divide by zero!" 
        else:
            return x/y 
        
                
    def Result(self,choice):
            if  choice ==    '1' : return  str(x) + " + " + str(y) + " = " + str(calcul.add(x,y))
            if  choice ==    '2' : return  str(x)+ " - "+ str(y)+ " = "+str(calcul.subtract(x,y))
            if  choice ==    '3' : return  str(x)+ " * "+ str(y)+ " = "+str(calcul.multiply(x,y))
            if  choice ==    '4' : return  str(x)+ " / "+ str(y)+ " = "+str(calcul.divide(x, y))
            if  choice ==    '5' : return  str(x)+ " ** "+ str(y)+ " = "+str(calcul.power(x, y))
            if  choice ==    '6' : return  " √ "+ str(x)+ " = "+str(calcul.square_root(x, y))

    def Border(self,string, length):
            return (string[0+i:length+i] for i in range(0, len(string), length))
                
        
while True:
        
        print(Menu)
       
        choice = input("\nEnter your choice (0/1/2/3/4/5/6/exit) : ")
        
        if choice == '0':
            count = '1'
        else:
            count = choice 
            
    
        if choice in options[0:-1]:
                try :
                    x = float(input("\nEnter the first number: "))

                    if choice != options[-2]: 
                        y = float(input("Enter the second number: "))

                except ValueError:
                    print("Please enter a valid number !!!")
                    print (separate)
                    continue

                calcul = Calculator(x,y)

                Display(calcul,count)       


        elif choice == options[-1]:
            print ("Bye Bye !!")
            break;

        else:
            print('\n choose a valid option !! \n')

        print (separate)
# Out:
# Select an operation.
#
#         0.All Operations
#         1.Add
#         2.Subtract
#         3.Multiply
#         4.Divide
#         5.Power
#         6.Square root
#         exit
#
# Enter your choice (0/1/2/3/4/5/6/exit) : 1
#
# Enter the first number: 34
# Enter the second number: 65
#
# 					 +--------------------+
#
# 					 | 34.0 + 65.0 = 99.0 |
#
# 					 +--------------------+
#
# --------------------------------------------------------------------------------------------------------
# Select an operation.
#
#         0.All Operations
#         1.Add
#         2.Subtract
#         3.Multiply
#         4.Divide
#         5.Power
#         6.Square root
#         exit
#
# Enter your choice (0/1/2/3/4/5/6/exit) : 2
#
# Enter the first number: 76
# Enter the second number: 34
#
# 					 +--------------------+
#
# 					 | 76.0 - 34.0 = 42.0 |
#
# 					 +--------------------+
#
# ...

# %% [markdown]
# # <h1> Task : Calculator (Version 2) </h1>

# %%
import math

space = "\n\t\t\t\t\t"
separate = "\n--------------------------------------------------------------------------------------------------------"
options = ('0','1','2','3','4','5','6','exit') 
Temp = None

Menu = """Select an operation.\n
        0.All 
        1.Add
        2.Subtract
        3.Multiply
        4.Divide
        5.Power
        6.Square root
        exit"""

def Display (calcul,count):
    
    while True:
            
            Result = calcul.Result(count)
            
            width = len(Result)

            print(space,'+-' + '-' * width + '-+')

            for line in calcul.Border(Result, width):
                print(space,'| {0:^{1}} |'.format(line, width))

            print(space,'+-' + '-'*(width) + '-+')

            if choice == options[0] and int(count) < 6 :
                count = str(int(count)+1)
            else:
                break;
                
                                              
        
class Calculator:
    
    def __init__(self,Number1,Number2):
        self.Number1 = Number1
        self.Number2 = Number2
    
    
    def add(self,x,y):
        
        return x + y 
    
    def subtract(self,x,y):
        
        return x - y
    
    def multiply(self,x,y):
        
        return x * y
    
    def power (self,x,y):
        
        return x ** y
    
    def square_root (self,x,y):
        
        if x < 0:
            x = x * (-1)    
        return math.sqrt(x)
    
    def divide(self,x,y): 
        if y == 0: 
            return "You can't divide by zero!" 
        else:
            return x/y
        
                
    def Result(self,choice):
            if  choice ==  options[1] : return  str(x) + " + " + str(y) + " = " + str(calcul.add(x,y))
            if  choice ==  options[2] : return  str(x)+ " - "+ str(y)+ " = "+str(calcul.subtract(x,y))
            if  choice ==  options[3] : return  str(x)+ " * "+ str(y)+ " = "+str(calcul.multiply(x,y))
            if  choice ==  options[4] : return  str(x)+ " / "+ str(y)+ " = "+str(calcul.divide(x, y))
            if  choice ==  options[5] : return  str(x)+ " ^ "+ str(y)+ " = "+str(calcul.power(x, y))
            if  choice ==  options[6] : return  " √ "+ str(x)+ " = "+str(calcul.square_root(x, y))

    def Border(self,string, length):
            return (string[0+i:length+i] for i in range(0, len(string), length))
                
 
print(Menu)

while True:   
       
        choice = input("\nEnter your choice (0 | 1 | 2 | 3 | 4 | 5 | 6 | exit) : ")
        
        
        if choice == '0':
            count = '1'
        else:
            count = choice 
            
    
        if choice in options[0:-1]:
                try :
                    if Temp is None: 
                        x = float(input("\nEnter a number: "))
                    else:
                        print (Temp)
                    
                    if choice == options[0]: y = float(input(" All operations "))
                    if choice == options[1]: y = float(input(" + "))
                    if choice == options[2]: y = float(input(" - "))
                    if choice == options[3]: y = float(input(" *  "))
                    if choice == options[4]: y = float(input(" / "))
                    if choice == options[5]: y = float(input(" ^ "))
                    if choice == options[6]: y = float(input(" √ "))

                except ValueError:
                    print("Please enter a valid number !!!")
                    print (separate)
                    continue    
                if Temp is None:         
                    calcul = Calculator(x,y)
                else:
                    x = Temp
                    calcul = Calculator(x,y)
                
                if choice == options[1]: Temp = calcul.add(x,y)
                if choice == options[2]: Temp = calcul.subtract(x,y)
                if choice == options[3]: Temp = calcul.multiply(x,y)
                if choice == options[4]: Temp = calcul.divide(x,y)
                if choice == options[5]: Temp = calcul.power(x,y)
                if choice == options[6]: Temp = calcul.square_root(x,y)

                Display(calcul,count)       


        elif choice == options[-1]:
            print ("Bye Bye !!")
            break;

        else:
            print('\n choose a valid option !! \n')

        print (separate)
# Out:
# Select an operation.
#
#         0.All
#         1.Add
#         2.Subtract
#         3.Multiply
#         4.Divide
#         5.Power
#         6.Square root
#         exit
#
# Enter your choice (0 | 1 | 2 | 3 | 4 | 5 | 6 | exit) : 1
#
# Enter a number: 2
#  + 3
#
# 					 +-----------------+
#
# 					 | 2.0 + 3.0 = 5.0 |
#
# 					 +-----------------+
#
# --------------------------------------------------------------------------------------------------------
#
# Enter your choice (0 | 1 | 2 | 3 | 4 | 5 | 6 | exit) : 4
# 5.0
#  / 3
#
# 					 +--------------------------------+
#
# 					 | 5.0 / 3.0 = 1.6666666666666667 |
#
# 					 +--------------------------------+
#
# --------------------------------------------------------------------------------------------------------
#
# Enter your choice (0 | 1 | 2 | 3 | 4 | 5 | 6 | exit) : 4
# 1.6666666666666667
#  / 5
#
# 					 +------------------------------------------------+
#
# 					 | 1.6666666666666667 / 5.0 = 0.33333333333333337 |
#
# ...
